# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path= "/content/drive/Othercomputers/My Laptop/UNT/Fall 2022/5290 NLP/Assingment/02/"

filename = "ngram_input.txt"

with open(path + filename) as f:
    content = f.readlines()
content = [ line for line in content if line != '\n' ]
len(content)
# Out:
# 758735

# %%
tokens = [t for l in content[:10000] for t in l.split() ]

# %%
tl = len(tokens)

# %%
tokens

# %%
import nltk
freq = nltk.FreqDist(tokens)
probs = {k: v/tl for (k,v) in freq.items()}
pvals = list(probs.values())
cumprobs = {k: sum(pvals[0:ix+1]) for ix, (k,v) in enumerate(probs.items())}
# Out:
#   File "<ipython-input-26-d11d6cf0030b>", line 5
#     cumprobs = {k: sum(pvals[0:ix+1]) for ix, (k,v) in enumerate(probs.items(:10))}
#                                                                              ^
# SyntaxError: invalid syntax

# %%
cfd_bigram = nltk.ConditionalFreqDist(nltk.bigrams(tokens))

# %%
cfd_bigram.items()

# %%
trigrams = nltk.trigrams(tokens)
condition_pairs = (((w0, w1), w2) for w0, w1, w2 in trigrams)
cfd_trigram = nltk.ConditionalFreqDist(condition_pairs)

# %%
cfd_trigram.items()
